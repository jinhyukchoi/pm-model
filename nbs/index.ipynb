# %%
#| hide
from pm_model.core import *

# %% [markdown]
# # pm-model
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install pm_model in Development mode

# %% [markdown]
# ```sh
# # make sure pm_model package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to pm_model
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/jinhyukchoi/pm-model.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c jinhyukchoi pm_model
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install pm_model
# ```
#
#
# [repo]: https://github.com/jinhyukchoi/pm-model
# [docs]: https://jinhyukchoi.github.io/pm-model/
# [pypi]: https://pypi.org/project/pm-model/
# [conda]: https://anaconda.org/jinhyukchoi/pm-model

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/jinhyukchoi/pm-model
# [docs]: https://jinhyukchoi.github.io/pm-model/
# [pypi]: https://pypi.org/project/pm-model/
# [conda]: https://anaconda.org/jinhyukchoi/pm-model

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
